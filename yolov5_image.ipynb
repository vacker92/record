# %%
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in C:\Users\vacke/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-5-18 Python-3.9.7 torch-1.11.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img = ['data/1.jpg']

results = model(img)

# %%
results.print()
# Out:
# image 1/1: 4000x2252 16 persons, 1 umbrella, 1 teddy bear
# Speed: 125.0ms pre-process, 71.0ms inference, 1.0ms NMS per image at shape (1, 3, 640, 384)

# %%
results.show()

# %%
results.save()
# Out:
# Saved 1 image to runs\detect\exp

# %%
results.xyxy[0]
# Out:
# tensor([[5.42963e+02, 2.55300e+03, 6.52898e+02, 2.86534e+03, 6.00543e-01, 0.00000e+00],
#         [7.73986e+02, 2.52963e+03, 9.14418e+02, 2.91125e+03, 5.77357e-01, 0.00000e+00],
#         [1.15756e+03, 2.49077e+03, 1.26910e+03, 2.83643e+03, 5.67352e-01, 0.00000e+00],
#         [4.36238e+02, 1.25016e+03, 1.85488e+03, 2.61600e+03, 4.88895e-01, 7.70000e+01],
#         [9.02992e+02, 2.52696e+03, 1.03169e+03, 2.89940e+03, 4.72626e-01, 0.00000e+00],
#         [6.97753e+02, 2.53987e+03, 7.95512e+02, 2.88970e+03, 4.53405e-01, 0.00000e+00],
#         [6.48891e+02, 2.55600e+03, 7.55535e+02, 2.88292e+03, 4.50687e-01, 0.00000e+00],
#         [1.09155e+03, 2.49965e+03, 1.18046e+03, 2.82820e+03, 4.28632e-01, 0.00000e+00],
#         [1.29809e+03, 2.49324e+03, 1.39286e+03, 2.82985e+03, 4.17739e-01, 0.00000e+00],
#         [4.90320e+02, 2.56340e+03, 6.18549e+02, 2.85595e+03, 4.15162e-01, 0.00000e+00],
#         [8.48002e+02, 2.53225e+03, 9.54344e+02, 2.91217e+03, 4.11051e-01, 0.00000e+00],
# ...

# %%
results.pandas().xyxy[0]
# Out:
#            xmin         ymin         xmax         ymax  confidence  class  \
# 0    542.963013  2552.998779   652.897766  2865.344727    0.600543      0
# 1    773.986267  2529.634766   914.418030  2911.253662    0.577357      0
# 2   1157.561279  2490.770020  1269.101196  2836.432617    0.567352      0
# 3    436.237640  1250.157837  1854.877319  2616.002441    0.488895     77
# 4    902.991882  2526.959473  1031.690186  2899.400879    0.472626      0
# 5    697.753418  2539.866943   795.512329  2889.700684    0.453405      0
# 6    648.890686  2555.996094   755.534546  2882.921143    0.450687      0
# 7   1091.546509  2499.645752  1180.457031  2828.200439    0.428632      0
# 8   1298.091187  2493.243896  1392.863525  2829.848145    0.417739      0
# 9    490.319641  2563.403076   618.549438  2855.954102    0.415162      0
# 10   848.001770  2532.254883   954.344482  2912.172363    0.411051      0
# 11  1013.364258  2524.533936  1107.968384  2862.823242    0.384759      0
# ...
